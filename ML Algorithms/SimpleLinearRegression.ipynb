# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("D:/Machine Learning/ML Algorithms/Datasets/placement.csv")

# %%
dataset.head(3)
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1

# %%
dataset.isnull().sum()
# Out:
# cgpa                    0
# placement_exam_marks    0
# placed                  0
# dtype: int64

# %%
x = dataset[["placement_exam_marks"]]
y = dataset['cgpa']

# %%
x.ndim
# Out:
# 2

# %%
sns.scatterplot(data=dataset,x='placement_exam_marks',y='cgpa')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[38]])
# Out:
# C:\Users\a1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6.95315928])

# %%
lr.score(x_test,y_test) #very bad score
# Out:
# -0.0035789194838917737

# %%
lr.coef_
# Out:
# array([-3.09809715e-05])

# %%
lr.intercept_
# Out:
# 6.954336558879301
